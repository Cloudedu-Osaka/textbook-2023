# %% [markdown]
# # 課題: ティコの天体観測
#
# ティコ・ブラーエの火星の観測結果を検証する
#
# * (1546&ndash;1601) [Tycho Brahe - Wikipedia](https://en.wikipedia.org/wiki/Tycho_Brahe)
# * (1571&ndash;1630) [Johannes Kepler - Wikipedia](https://en.wikipedia.org/wiki/Johannes_Kepler)

# %% [markdown]
# ## ルドルフ表

# %% [markdown]
# * (1627) [Rudolphine Tables - Wikipedia](https://en.wikipedia.org/wiki/Rudolphine_Tables)
#     - (1576&ndash;1612) [Rudolf II, Holy Roman Emperor - Wikipedia](https://en.wikipedia.org/wiki/Rudolf_II,_Holy_Roman_Emperor)

# %% [markdown]
# ![fig-01](https://upload.wikimedia.org/wikipedia/commons/7/75/8107-2Keplertp.png)

# %% [markdown]
# * [Mathematical Treasures - Johann Kepler's Rudolphine Tables | Mathematical Association of America](https://www.maa.org/press/periodicals/convergence/mathematical-treasures-johann-keplers-rudolphine-tables)
# * [Tabulæ Rudolphinæ, quibus astronomicæ scientiæ temporum longinquitate collapsæ restauratio continetur, a Tychone, ex illustri & generosa Braheorum in Regno Daniæ familia oriundo equite, primum animo concepta et destinata A.C. MDLXIV, tracta per annos XXV, ... tandem traducta in Germaniam, in que aulam et nomen Rudolphi Imp. anno MDIIC., tabulas ipsas ... continuavit ... Joannes Keplerus, qui idem opus hoc in publicum extulit : Kepler, Johannes : Free Download, Borrow, and Streaming : Internet Archive](https://archive.org/details/den-kbd-pil-130018170346-001/)
#     - (p.161&ndash;) 数表

# %% [markdown]
# ## ティコの観測ノート (全集)

# %% [markdown]
# * "Tychonis Brahe Dani Opera Omnia" [Internet Archive: Digital Library of Free & Borrowable Books, Movies, Music & Wayback Machine](https://archive.org/search?query=%22Opera+omnia%2C+edidit+I.L.E.+Dreyer%22)

# %% [markdown]
# * https://www.google.com/search?q=tychonic+system&sxsrf=ALiCzsZWvcxSV9IZ9qWS2TOWN0zCZekPOg:1657589719899&source=lnms&tbm=vid&sa=X&ved=2ahUKEwjl5r_zmvL4AhWVp1YBHduDCtgQ_AUoAnoECAIQBA&biw=960&bih=1096&dpr=1

# %% [markdown]
# ## 惑星の逆行
#
# * [Apparent retrograde motion - Wikipedia](https://en.wikipedia.org/wiki/Apparent_retrograde_motion)

# %%
# %%ai_ask
# 惑星の逆行について
# Out:
# 惑星の逆行とは、地球から見た他の惑星の動きが、一定期間にわたって逆方向に見える現象のことです。これは、地球と他の惑星が公転する軌道の関係によって起こります。逆行は、天文学的な観測において重要な現象であり、惑星の運動や軌道の解析に役立ちます。

# %% [markdown]
# * [Visualizing Tycho Brahe's Mars Observations](http://www.pafko.com/tycho/observe.html)

# %% [markdown]
# ### 地球から観測した火星の逆行をプロットする

# %% [markdown]
# * [Astronomical coordinate systems - Wikipedia](https://en.wikipedia.org/wiki/Astronomical_coordinate_systems) (天球座標系)
#     - [Equatorial coordinate system - Wikipedia](https://en.wikipedia.org/wiki/Equatorial_coordinate_system) (赤道座標系)
#     - [Ecliptic coordinate system - Wikipedia](https://en.wikipedia.org/wiki/Ecliptic_coordinate_system) (黄道座標系)

# %% [markdown]
# * Center point (origin)
#     - Earth (Geocentric)
#     - Sun (Heliocentric)

# %%
# %%ai_continue
# heliocentricとgeocentricに適切な日本語はありますか？
# Out:
# heliocentricは「太陽中心の」、geocentricは「地球中心の」と訳されます。

# %%
# %%ai_continue
# 赤道座標と黄道座標について
# Out:
# 赤道座標とは、天球上の赤道を基準にして星座の位置を表す座標系です。赤道座標では、天球上の赤道を0度とし、北極星を90度として、その他の星座の位置を角度で表します。
#
# 一方、黄道座標とは、天球上の黄道を基準にして星座の位置を表す座標系です。黄道座標では、天球上の黄道を0度とし、春分点を90度として、その他の星座の位置を角度で表します。
#
# 赤道座標は、天体の運動を追跡するのに適しており、黄道座標は、太陽系の天体の運動を追跡するのに適しています。

# %%
# %%ai_continue
# 太陽中心の赤道座標系と黄道座標系に違いはありますか？
# Out:
# 太陽中心の赤道座標系と黄道座標系は、地球中心の赤道座標系と黄道座標系と同様に、基準点が異なるために異なります。
#
# 太陽中心の赤道座標系では、基準面は太陽の赤道面であり、基準点は春分点です。一方、太陽中心の黄道座標系では、基準面は太陽の黄道面であり、基準点は春分点です。
#
# 地球中心の赤道座標系と黄道座標系と同様に、太陽中心の赤道座標系と黄道座標系も、天体の位置を表すために使用されます。太陽系の天体の運動を追跡するためには、太陽中心の座標系が使用されます。

# %%
# %%ai_continue
# 太陽の赤道面と黄道面は違いますか？
# Out:
# はい、太陽の赤道面と黄道面は異なります。太陽の赤道面は、太陽の自転軸に対して傾いており、地球から見ると太陽の北極と南極が存在します。一方、太陽の黄道面は、地球の公転面と太陽の赤道面の交点を基準に定義され、地球の公転軌道と交差する面です。太陽の黄道面は、地球から見ると、黄道と呼ばれる惑星の軌道面と交わる点が存在します。

# %% [markdown]
# * [IoannisNasios/solarsystem: Python Library for Planetary Position Calculations](https://github.com/IoannisNasios/solarsystem)

# %%
import solarsystem

# %%
H = solarsystem.Heliocentric(year=2020, month=1, day=1, hour=12, minute=0 )

# %%
H.planets()
# Out:
# {'Mercury': (263.83033031837124, -4.057599521202387, 0.4659797616165433),
#  'Venus': (5.228267566604352, -3.2222136733454763, 0.7262291936644325),
#  'Earth': (100.5289245858366, 0.0, 0.9833180862528658),
#  'Mars': (214.38221616457562, 0.4891253753974966, 1.5891803735433014),
#  'Jupiter': (276.10498313633025, 0.10374961050190847, 5.228112674603031),
#  'Saturn': (292.512767008796, 0.05134540100060894, 10.05212207219113),
#  'Uranus': (35.35030250536327, 359.5159538071305, 19.809355998647174),
#  'Neptune': (348.0172656026235, -1.039905299592724, 29.914939199387618),
#  'Pluto': (292.7499413549187, 359.3290225249272, 33.87680754878506),
#  'Ceres': (290.86531789432115, -5.404211011344595, 2.9204640444111933),
#  'Chiron': (4.327136751763591, 2.943432379699923, 18.810534112295773),
#  'Eris': (23.548094614031402, -11.744274334977886, 95.99830322945104)}

# %%
G = solarsystem.Geocentric(year=1584, month=1, day=1, hour=12, minute=0 )

# %%
G.position()['Mars']
# Out:
# (277.79300336467145, -0.8614115012318369, 2.4085976885499947)

# %%
l = []
for y in range(1583,1600):
    for m in range(1,13):
        for d in range(1,30):
            G = solarsystem.Geocentric(year=y, month=m, day=d, hour=12, minute=0 )
            l.append(G.position()['Mars'][0])
l
# Out:
# [110.54670806000699,
#  110.16787295581473,
#  109.78356391381628,
#  109.3945287639193,
#  109.00153400645357,
#  108.60536171405973,
#  108.20680626865511,
#  107.80667096459355,
#  107.40576451564729,
#  107.0048975015344,
#  106.60487879506202,
#  106.20651200724353,
#  105.81059199122618,
#  105.41790144082289,
#  105.02920762162127,
#  104.64525926590133,
#  104.26678366319733,
#  103.89448397076296,
#  103.52903676812653,
#  103.17108987146091,
#  102.82126042268854,
#  102.48013325992697,
#  102.14825957532226,
#  101.82615585808891,
#  101.51430312017796,
#  101.21314639474157,
#  100.9230944981028,
#  100.64452003938759,
#  100.37775966313598,
#  99.65120092048898,
#  99.43436392765742,
#  99.23050710816806,
#  99.03976698337526,
#  98.86225066558447,
#  98.69803724504641,
#  98.54717923073082,
#  98.40970402965412,
#  98.2856154477501,
#  98.17489519952414,
#  98.07750441239294,
#  97.99338511598835,
#  97.92246170524669,
#  97.86464237010796,
#  97.81982048340406,
# ...

# %%
len(l)
# Out:
# 5916

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.radians(l)
# Out:
# array([1.92940403, 1.92279211, 1.91608465, ..., 2.41407093, 2.41289642,
#        2.4114855 ])

# %%
plt.plot(range(5916), -np.radians(l))

# %% [markdown]
# ### 位相アンラップ処理をして逆行だけを取り出す
#
# * 火星の公転周期: 687日
#   - 約1年11ヶ月で逆行が観測できる

# %%
plt.plot(range(5916), np.unwrap(np.radians(l))-np.linspace(0,57,num=5916))

# %% [markdown]
# ### 時間指定が厄介なので、他のソフトを使う

# %% [markdown]
# * [The PyEphem Tutorial — PyEphem home page](https://rhodesmill.org/pyephem/tutorial.html)
# * [Python で日食計算](http://www.sci-museum.kita.osaka.jp/~egoshi/astronomy/python/python_solar_eclipse.html)

# %%
import ephem
import matplotlib.pyplot as plt
import numpy as np

# %%
m = ephem.Mars()

# %%
m.compute('1584/1/1')

# %%
# 日心経度, 日心緯度
m.hlon, m.hlat
# Out:
# (4.880208969116211, -0.02591746859252453)

# %%
m0 = ephem.Mars(ephem.Date('1584/1/1'))
m1 = ephem.Mars(ephem.Date('1584/1/1')+1)

# %%
def hops(body): return body.hlon, body.hlat

# %%
ephem.separation(hops(m0), hops(m1))
# Out:
# 0.010442553936505066

# %%
# 赤経, 赤緯
m.ra, m.dec
# Out:
# (4.89811066895129, -0.4190875793738444)

# %% [markdown]
# * [赤経 - Wikipedia](https://ja.wikipedia.org/wiki/%E8%B5%A4%E7%B5%8C)
# * [赤緯 - Wikipedia](https://ja.wikipedia.org/wiki/%E8%B5%A4%E7%B7%AF)

# %%
d = ephem.Date('1582/11/1')
l = []
for _ in range(1,365*(1600-1582)):
    m0 = ephem.Mars(ephem.Date(d))
    l.append(m0.ra)
    d+=1
l;

# %%
len(l)
# Out:
# 6569

# %%
#plt.plot(range(len(l)), np.unwrap(l)-np.linspace(0,60,num=len(l)))

# %%
plt.plot(range(len(l)), -np.array(l))

# %% [markdown]
# ## チコの観測の検証
#
# * [Visualizing Tycho Brahe's Mars Observations](http://www.pafko.com/tycho/observe.html)

# %%
import pandas as pd
import datetime

# %%
df = pd.read_excel('http://www.pafko.com/tycho/mars.xls', header=5)

# %%
df
# Out:
#      Unnamed: 0  Year                        Day          Time  \
# 0           NaN  1582    DIE 12 NOUEMBRIS, MANE.           NaN
# 1           NaN  1582           DIE 30 DECEMBRIS           NaN
# 2           NaN  1582           DIE 27 DECEMBRIS           NaN
# 3           NaN  1583  DIE 18 JANUARIJ, VESPERI.           NaN
# 4           NaN  1584     DIE 13 NOUEMBRIS, A.M.  H.13 26 P.M.
# ..          ...   ...                        ...           ...
# 918         NaN  1600               24 Januarij.           NaN
# 919         NaN  1600              Die 2 Martij.     H.10 P.M.
# 920         NaN  1600               Die 9 Martij  H.9 1/2 P.M.
# 921         NaN  1600              Die 15 Martij       H.9 1/3
# 922         NaN  1600              Die 16 Martij      H. 9 1/4
#
#                                                  Quote  Volume  Page  \
# 0                             Declinatio [MS]  23  7 B      10   174
# ...

# %%
print(ephem.Date(ephem.Date(datetime.datetime(1584,11,23,13,26))+(584484.88-578883.06)))
# Out:
# 1600/3/26 09:06:48

# %%
df2=df.iloc[:,[14,20]]

# %%
df2.set_index('Days since 1 AD', inplace=True)

# %%
#df2.index.values - df2.index.values[0]

# %%
#df2.iloc[:,0].values

# %%
plt.scatter(range(len(l)), -np.array(l)/3+1.1, marker='.', alpha=0.01)
plt.scatter(df2.index.values - df2.index.values[0],
            np.radians(df2.iloc[:,0].values),
            c=None, marker='.', alpha=.5)
plt.show()

# %% [markdown]
# 後半のデータを修正･･･

# %%
import bisect
bisect.bisect(df2.index.values - df2.index.values[0], 3000)
# Out:
# 249

# %%
x=np.concatenate([
    df2.iloc[:268,0].values,
    df2.iloc[268,0] * 2 - df2.iloc[268:,0].values])

# %%
plt.scatter(range(len(l)), -np.array(l)/3+1.1, marker='.', alpha=0.01)
plt.scatter(df2.index.values - df2.index.values[0],
            np.radians(x),
            c=None, marker='.', alpha=.5)
plt.show()
